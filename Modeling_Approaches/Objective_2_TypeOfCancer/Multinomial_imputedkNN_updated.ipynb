# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report


import pandas as pd


df = pd.read_csv(r"C:\Users\acerA\Downloads\Combined_df2_imputedkNN.csv")
df


unique_cancer_values = df['Cancer'].unique()
print('Unique Cancer values:', unique_cancer_values)

blood_cancer_values = ['AML', 'CLL', 'DLBCL', 'MYEL']

df['Cancer'] = df['Cancer'].replace(blood_cancer_values, 'Blood_cancer')

unique_cancer_values_updated = df['Cancer'].unique()
print('Updated Unique Cancer values:', unique_cancer_values_updated)

print(df.head())




df




unique_cancer_values = df['Cancer'].unique()
print('Unique Cancer values:', unique_cancer_values)

blood_cancer_values = ['AML', 'CLL', 'DLBCL', 'MYEL']

df['Cancer'] = df['Cancer'].replace(blood_cancer_values, 'Blood_cancer')
df['Cancer']

unique_cancer_values_with_blood_cancer = df['Cancer'].unique()
unique_cancer_values_with_blood_cancer

unique_cancer_values = df['Cancer'].unique()
print('Unique Cancer values:', unique_cancer_values)



df



from sklearn.preprocessing import LabelEncoder
import pandas as pd



encoder = LabelEncoder()



df['Target'] = encoder.fit_transform(df['Cancer'])
df['Target']
df


column_to_move = 'Target'
new_position = 4

column_data = df.pop('Target')

df.insert(new_position, column_to_move, column_data)



df



index = df.columns.get_loc('Target')
index



X = df.iloc[:, 6:].values
X



y = df.iloc[:, 4].values
y



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100, shuffle=True, stratify=y)

from sklearn.model_selection import StratifiedKFold

kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=100)

X_train



X_test



y_test



y_train



scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)



scaler



X_train



X_test



model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=200)



model



model.fit(X_train, y_train)



y_pred = model.predict(X_test)



y_pred



print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))



print("Model Coefficients:")
print(model.coef_)
# Out:
# Unique Cancer values: ['Ctrl' 'ESO' 'AML' 'BRC' 'CLL' 'CRC' 'CVX' 'ENDC' 'GLIOM' 'LUNGC' 'LYMPH'
#  'MYEL' 'OVC' 'PRC' 'HODG']
# Updated Unique Cancer values: ['Ctrl' 'ESO' 'Blood_cancer' 'BRC' 'CRC' 'CVX' 'ENDC' 'GLIOM' 'LUNGC'
#  'LYMPH' 'OVC' 'PRC' 'HODG']
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Sample_ID Cancer    Q15389   P29965  \
# 0             0             0         0.0     PM910   Ctrl  10.12895  5.62622
# 1             1             1         1.0     PM396   Ctrl   8.67289  5.18821
# 2             2             2         2.0     PM190   Ctrl   9.99567  6.38876
# 3             3             3         3.0     PM270   Ctrl   8.26407  5.06228
# 4             4             4         4.0     PM656   Ctrl   9.08833  5.95005
#
#     P49763   Q02763    P01127  ...   P09382   Q16790    P26842   P14210  \
# 0  7.72902  8.47530  10.08926  ...  8.54519  4.20874  10.61404  8.37166
# 1  8.25523  9.06271   8.89866  ...  8.25401  3.46839  10.77271  8.36820
# 2  8.44263  8.42102  10.08508  ...  8.75887  4.65936  11.03062  9.18464
# 3  8.13429  8.66165   8.75925  ...  8.75741  4.44633  10.47952  8.65548
# 4  8.37830  8.29127   9.43936  ...  8.48018  3.81634  10.59295  8.63758
#
#     P43489   O75144   O43927   P32970   Q8WXI7   P10144
# 0  4.99296  7.78219  7.03584  4.81481  3.58965  4.13563
# 1  4.92422  7.47997  8.05700  3.98900  4.78155  3.14840
# 2  5.60743  7.92803  8.77261  4.80189  5.16350  4.29062
# 3  5.54289  9.29458  8.64028  4.04045  5.59217  3.75295
# 4  5.16271  7.41098  8.29143  4.59594  4.91665  4.10381
#
# [5 rows x 54 columns]
# Unique Cancer values: ['Ctrl' 'ESO' 'Blood_cancer' 'BRC' 'CRC' 'CVX' 'ENDC' 'GLIOM' 'LUNGC'
#  'LYMPH' 'OVC' 'PRC' 'HODG']
# Unique Cancer values: ['Ctrl' 'ESO' 'Blood_cancer' 'BRC' 'CRC' 'CVX' 'ENDC' 'GLIOM' 'LUNGC'
#  'LYMPH' 'OVC' 'PRC' 'HODG']
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Accuracy: 0.5931758530183727
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0
#   -4.54581643e-01  9.10274152e-01 -5.98110719e-02 -5.03347921e-01
#    1.01692197e-01 -2.86780026e-01 -7.16055285e-02 -8.94817814e-01
#    5.12640089e-01  3.15910455e-01  7.12470671e-01  1.07440918e+00
#    4.74798009e-03 -2.32574682e-01  4.45388249e-01  7.06095943e-02
#   -8.61380166e-01 -3.17344028e-01 -7.04354340e-01 -1.05687687e+00
#   -2.36623520e-01 -9.79799306e-01 -6.97454648e-01  5.44809080e-01
#   -1.23673638e+00 -2.28374181e-01 -1.26872035e-01  1.47634877e+00
#   -1.35449475e+00]
#  [-3.79707112e-02 -7.61064797e-01  1.09848942e+00  5.21342377e-01
#    6.18431535e-02  3.04997832e-01 -1.57746397e+00  1.38180744e+00
#    1.32576537e+00 -2.21428578e-02  6.48231223e-01 -7.00443320e-01
#    9.50490475e-01  2.44013550e-01 -2.15504216e-01  2.66318791e-01
#    6.32144234e-02  1.86247315e-01  6.65926447e-02 -1.51135127e-01
#   -8.67605506e-01  1.12897589e-01  1.53623913e-01  8.30303551e-01
#    1.39398899e-01  1.20529711e-01  2.78256342e-03  1.26446742e-01
#   -2.64811126e-01 -1.48777277e-01  3.85800825e-01 -6.29234817e-02
#   -3.28090872e-01  8.26207664e-01 -6.10764028e-01  1.15257823e+00
#    3.05391695e-02 -2.18913393e-01 -1.20898360e+00 -4.04957164e-01
#   -6.37808849e-02 -2.07429403e-01 -3.78151462e-01 -4.26083186e-01
#   -1.44603411e-01 -9.22048437e-01 -1.28179621e+00 -4.45702623e-01
#    1.13002846e+00]]

# %%
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import label_binarize

y_test_bin = label_binarize(y_test, classes=np.unique(y))

y_pred_prob = model.predict_proba(X_test)

roc_auc = roc_auc_score(y_test_bin, y_pred_prob, multi_class='ovr') 

print("ROC AUC Score: ", roc_auc)
# Out:
# ROC AUC Score:  0.9122096526280349

# %%
from sklearn.metrics import classification_report

print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.28      0.26      0.27        31
#            1       0.61      0.63      0.62        27
#            2       0.43      0.50      0.46        44
#            3       0.35      0.40      0.37        20
#            4       1.00      1.00      1.00        34
#            5       0.36      0.20      0.26        20
#            6       1.00      1.00      1.00        18
#            7       0.76      0.55      0.64        29
#            8       1.00      1.00      1.00        33
#            9       0.52      0.57      0.54        54
#           10       0.83      0.45      0.59        11
#           11       0.50      0.59      0.54        27
#           12       0.40      0.42      0.41        33
#
#     accuracy                           0.59       381
#    macro avg       0.62      0.58      0.59       381
# weighted avg       0.60      0.59      0.59       381

# %%
from sklearn.metrics import f1_score

f1_macro = f1_score(y_test, y_pred, average='macro')
print("F1-score (Macro Average):", f1_macro)

f1_weighted = f1_score(y_test, y_pred, average='weighted')
print("F1-score (Weighted Average):", f1_weighted)

f1_micro = f1_score(y_test, y_pred, average='micro')
print("F1-score (Micro Average):", f1_micro)
# Out:
# F1-score (Macro Average): 0.5926458807268395
# F1-score (Weighted Average): 0.592049832788313
# F1-score (Micro Average): 0.5931758530183727
